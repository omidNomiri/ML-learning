# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

# %%
dataset = load_digits()
dataset.data.shape
# Out:
# (1797, 64)

# %%
test = 100
img = dataset.images[test]
plt.imshow(img, cmap="gray")
dataset.target[test]
# Out:
# 4

# %%
dataset = load_digits()
X = dataset.data
Y = dataset.target

# One-hot encode target
Y = np.eye(10)[Y]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def softmax(X):
    exp_X = np.exp(X - np.max(X, axis=1, keepdims=True))
    return exp_X / np.sum(exp_X, axis=1, keepdims=True)

def root_mean_squared_error(Y_pred, Y_test):
    return np.sqrt(np.mean((Y_pred - Y_test) ** 2))

def calculate_accuracy(Y_pred, Y_true):
    return np.mean(np.argmax(Y_pred, axis=1) == np.argmax(Y_true, axis=1))

# %%
# Initialize network parameters
Dimension_input = x_train.shape[1]
Dimension_output = y_train.shape[1]

H1 = 128
H2 = 32

lr = 0.001
epochs = 80

# Initialize weights and biases
W1 = np.random.randn(Dimension_input, H1)
W2 = np.random.randn(H1, H2)
W3 = np.random.randn(H2, Dimension_output)

B1 = np.random.randn(1, H1)
B2 = np.random.randn(1, H2)
B3 = np.random.randn(1, Dimension_output)

accuracy_train_list, accuracy_test_list = [], []
loss_train_list, loss_test_list = [], []

# %%
# Training loop
for epoch in range(epochs):
    # Forward pass for the entire dataset (vectorized)
    Z1 = sigmoid(np.dot(x_train, W1) + B1)
    Z2 = sigmoid(np.dot(Z1, W2) + B2)
    Y_pred_train = softmax(np.dot(Z2, W3) + B3)
    
    # Backward pass (vectorized)
    error = Y_pred_train - y_train
    
    grad_W3 = np.dot(Z2.T, error)
    grad_B3 = np.sum(error, axis=0, keepdims=True)

    error = np.dot(error, W3.T) * Z2 * (1 - Z2)
    grad_W2 = np.dot(Z1.T, error)
    grad_B2 = np.sum(error, axis=0, keepdims=True)

    error = np.dot(error, W2.T) * Z1 * (1 - Z1)
    grad_W1 = np.dot(x_train.T, error)
    grad_B1 = np.sum(error, axis=0, keepdims=True)

    # Update weights and biases
    W1 -= lr * grad_W1
    B1 -= lr * grad_B1
    W2 -= lr * grad_W2
    B2 -= lr * grad_B2
    W3 -= lr * grad_W3
    B3 -= lr * grad_B3

    # Evaluate training loss and accuracy
    loss_train = root_mean_squared_error(Y_pred_train, y_train)
    accuracy_train = calculate_accuracy(Y_pred_train, y_train)

    # Forward pass for the test set
    Z1_test = sigmoid(np.dot(x_test, W1) + B1)
    Z2_test = sigmoid(np.dot(Z1_test, W2) + B2)
    Y_pred_test = softmax(np.dot(Z2_test, W3) + B3)

    # Evaluate test loss and accuracy
    loss_test = root_mean_squared_error(Y_pred_test, y_test)
    accuracy_test = calculate_accuracy(Y_pred_test, y_test)

    accuracy_train_list.append(accuracy_train)
    accuracy_test_list.append(accuracy_test)
    loss_train_list.append(loss_train)
    loss_test_list.append(loss_test)

    print(f"Epoch {epoch+1}/{epochs} - loss train: {loss_train:.4f}, accuracy train: {accuracy_train:.4f}")
    print(f"                  loss test: {loss_test:.4f}, accuracy test: {accuracy_test:.4f}")

print("\n\nTraining Completed!")
# Out:
# Epoch 1/80 - loss train: 0.3453, accuracy train: 0.1406
#                   loss test: 0.3476, accuracy test: 0.1306
# Epoch 2/80 - loss train: 0.3442, accuracy train: 0.1371
#                   loss test: 0.3092, accuracy test: 0.1917
# Epoch 3/80 - loss train: 0.3068, accuracy train: 0.1990
#                   loss test: 0.3044, accuracy test: 0.2333
# Epoch 4/80 - loss train: 0.2967, accuracy train: 0.2637
#                   loss test: 0.2935, accuracy test: 0.2500
# Epoch 5/80 - loss train: 0.2869, accuracy train: 0.2944
#                   loss test: 0.2878, accuracy test: 0.3139
# Epoch 6/80 - loss train: 0.2825, accuracy train: 0.3166
#                   loss test: 0.2878, accuracy test: 0.2944
# Epoch 7/80 - loss train: 0.2803, accuracy train: 0.3424
#                   loss test: 0.2839, accuracy test: 0.3667
# Epoch 8/80 - loss train: 0.2792, accuracy train: 0.3542
#                   loss test: 0.2739, accuracy test: 0.3639
# Epoch 9/80 - loss train: 0.2669, accuracy train: 0.4245
#                   loss test: 0.2738, accuracy test: 0.4139
# Epoch 10/80 - loss train: 0.2671, accuracy train: 0.4335
#                   loss test: 0.2677, accuracy test: 0.4250
# Epoch 11/80 - loss train: 0.2587, accuracy train: 0.4767
#                   loss test: 0.2691, accuracy test: 0.4556
# Epoch 12/80 - loss train: 0.2605, accuracy train: 0.4760
#                   loss test: 0.2588, accuracy test: 0.4806
# Epoch 13/80 - loss train: 0.2515, accuracy train: 0.5233
#                   loss test: 0.2643, accuracy test: 0.4778
# Epoch 14/80 - loss train: 0.2533, accuracy train: 0.5184
#                   loss test: 0.2474, accuracy test: 0.5694
# Epoch 15/80 - loss train: 0.2401, accuracy train: 0.5825
#                   loss test: 0.2532, accuracy test: 0.5361
# Epoch 16/80 - loss train: 0.2396, accuracy train: 0.5804
#                   loss test: 0.2393, accuracy test: 0.5917
# Epoch 17/80 - loss train: 0.2300, accuracy train: 0.6284
#                   loss test: 0.2441, accuracy test: 0.5806
# Epoch 18/80 - loss train: 0.2293, accuracy train: 0.6291
#                   loss test: 0.2312, accuracy test: 0.6417
# Epoch 19/80 - loss train: 0.2206, accuracy train: 0.6625
#                   loss test: 0.2358, accuracy test: 0.6083
# Epoch 20/80 - loss train: 0.2198, accuracy train: 0.6639
#                   loss test: 0.2247, accuracy test: 0.6778
# Epoch 21/80 - loss train: 0.2122, accuracy train: 0.6994
#                   loss test: 0.2279, accuracy test: 0.6306
# Epoch 22/80 - loss train: 0.2107, accuracy train: 0.6966
#                   loss test: 0.2200, accuracy test: 0.6861
# Epoch 23/80 - loss train: 0.2057, accuracy train: 0.7279
#                   loss test: 0.2221, accuracy test: 0.6556
# Epoch 24/80 - loss train: 0.2037, accuracy train: 0.7237
#                   loss test: 0.2154, accuracy test: 0.7000
# Epoch 25/80 - loss train: 0.1999, accuracy train: 0.7446
#                   loss test: 0.2150, accuracy test: 0.6889
# Epoch 26/80 - loss train: 0.1965, accuracy train: 0.7481
#                   loss test: 0.2103, accuracy test: 0.7194
# Epoch 27/80 - loss train: 0.1934, accuracy train: 0.7641
#                   loss test: 0.2084, accuracy test: 0.7056
# Epoch 28/80 - loss train: 0.1894, accuracy train: 0.7738
#                   loss test: 0.2054, accuracy test: 0.7250
# Epoch 29/80 - loss train: 0.1864, accuracy train: 0.7829
#                   loss test: 0.2026, accuracy test: 0.7250
# Epoch 30/80 - loss train: 0.1822, accuracy train: 0.7926
#                   loss test: 0.2019, accuracy test: 0.7167
# Epoch 31/80 - loss train: 0.1807, accuracy train: 0.7940
#                   loss test: 0.1977, accuracy test: 0.7389
# Epoch 32/80 - loss train: 0.1762, accuracy train: 0.8086
#                   loss test: 0.1977, accuracy test: 0.7333
# Epoch 33/80 - loss train: 0.1742, accuracy train: 0.8100
#                   loss test: 0.1935, accuracy test: 0.7361
# Epoch 34/80 - loss train: 0.1704, accuracy train: 0.8177
#                   loss test: 0.1947, accuracy test: 0.7389
# Epoch 35/80 - loss train: 0.1694, accuracy train: 0.8246
#                   loss test: 0.1898, accuracy test: 0.7528
# Epoch 36/80 - loss train: 0.1655, accuracy train: 0.8288
#                   loss test: 0.1911, accuracy test: 0.7500
# Epoch 37/80 - loss train: 0.1639, accuracy train: 0.8427
#                   loss test: 0.1860, accuracy test: 0.7694
# Epoch 38/80 - loss train: 0.1603, accuracy train: 0.8434
#                   loss test: 0.1881, accuracy test: 0.7583
# Epoch 39/80 - loss train: 0.1591, accuracy train: 0.8601
#                   loss test: 0.1827, accuracy test: 0.7778
# Epoch 40/80 - loss train: 0.1556, accuracy train: 0.8580
#                   loss test: 0.1852, accuracy test: 0.7667
# Epoch 41/80 - loss train: 0.1544, accuracy train: 0.8678
#                   loss test: 0.1797, accuracy test: 0.7806
# Epoch 42/80 - loss train: 0.1510, accuracy train: 0.8678
#                   loss test: 0.1824, accuracy test: 0.7806
# Epoch 43/80 - loss train: 0.1499, accuracy train: 0.8789
#                   loss test: 0.1768, accuracy test: 0.7917
# Epoch 44/80 - loss train: 0.1470, accuracy train: 0.8782
#                   loss test: 0.1800, accuracy test: 0.7861
# Epoch 45/80 - loss train: 0.1458, accuracy train: 0.8859
#                   loss test: 0.1742, accuracy test: 0.8028
# Epoch 46/80 - loss train: 0.1431, accuracy train: 0.8866
#                   loss test: 0.1773, accuracy test: 0.7944
# Epoch 47/80 - loss train: 0.1418, accuracy train: 0.8963
#                   loss test: 0.1717, accuracy test: 0.8056
# Epoch 48/80 - loss train: 0.1392, accuracy train: 0.8998
#                   loss test: 0.1748, accuracy test: 0.7972
# Epoch 49/80 - loss train: 0.1378, accuracy train: 0.9054
#                   loss test: 0.1696, accuracy test: 0.8056
# Epoch 50/80 - loss train: 0.1355, accuracy train: 0.9061
#                   loss test: 0.1724, accuracy test: 0.8000
# Epoch 51/80 - loss train: 0.1342, accuracy train: 0.9130
#                   loss test: 0.1678, accuracy test: 0.8167
# Epoch 52/80 - loss train: 0.1322, accuracy train: 0.9116
#                   loss test: 0.1703, accuracy test: 0.8083
# Epoch 53/80 - loss train: 0.1310, accuracy train: 0.9221
#                   loss test: 0.1661, accuracy test: 0.8194
# Epoch 54/80 - loss train: 0.1292, accuracy train: 0.9151
#                   loss test: 0.1682, accuracy test: 0.8139
# Epoch 55/80 - loss train: 0.1281, accuracy train: 0.9241
#                   loss test: 0.1645, accuracy test: 0.8250
# Epoch 56/80 - loss train: 0.1265, accuracy train: 0.9221
#                   loss test: 0.1662, accuracy test: 0.8139
# Epoch 57/80 - loss train: 0.1254, accuracy train: 0.9255
#                   loss test: 0.1629, accuracy test: 0.8278
# Epoch 58/80 - loss train: 0.1240, accuracy train: 0.9235
#                   loss test: 0.1644, accuracy test: 0.8222
# Epoch 59/80 - loss train: 0.1229, accuracy train: 0.9269
#                   loss test: 0.1613, accuracy test: 0.8278
# Epoch 60/80 - loss train: 0.1216, accuracy train: 0.9269
#                   loss test: 0.1626, accuracy test: 0.8250
# Epoch 61/80 - loss train: 0.1205, accuracy train: 0.9311
#                   loss test: 0.1597, accuracy test: 0.8306
# Epoch 62/80 - loss train: 0.1193, accuracy train: 0.9311
#                   loss test: 0.1608, accuracy test: 0.8222
# Epoch 63/80 - loss train: 0.1182, accuracy train: 0.9360
#                   loss test: 0.1583, accuracy test: 0.8333
# Epoch 64/80 - loss train: 0.1171, accuracy train: 0.9346
#                   loss test: 0.1592, accuracy test: 0.8278
# Epoch 65/80 - loss train: 0.1161, accuracy train: 0.9374
#                   loss test: 0.1569, accuracy test: 0.8333
# Epoch 66/80 - loss train: 0.1151, accuracy train: 0.9367
#                   loss test: 0.1577, accuracy test: 0.8306
# Epoch 67/80 - loss train: 0.1141, accuracy train: 0.9408
#                   loss test: 0.1557, accuracy test: 0.8417
# Epoch 68/80 - loss train: 0.1131, accuracy train: 0.9395
#                   loss test: 0.1562, accuracy test: 0.8361
# Epoch 69/80 - loss train: 0.1122, accuracy train: 0.9415
#                   loss test: 0.1544, accuracy test: 0.8444
# Epoch 70/80 - loss train: 0.1112, accuracy train: 0.9436
#                   loss test: 0.1548, accuracy test: 0.8417
# Epoch 71/80 - loss train: 0.1103, accuracy train: 0.9429
#                   loss test: 0.1532, accuracy test: 0.8500
# Epoch 72/80 - loss train: 0.1094, accuracy train: 0.9436
#                   loss test: 0.1534, accuracy test: 0.8444
# Epoch 73/80 - loss train: 0.1085, accuracy train: 0.9457
#                   loss test: 0.1519, accuracy test: 0.8500
# Epoch 74/80 - loss train: 0.1077, accuracy train: 0.9464
#                   loss test: 0.1521, accuracy test: 0.8472
# Epoch 75/80 - loss train: 0.1068, accuracy train: 0.9492
#                   loss test: 0.1508, accuracy test: 0.8528
# Epoch 76/80 - loss train: 0.1061, accuracy train: 0.9485
#                   loss test: 0.1509, accuracy test: 0.8472
# Epoch 77/80 - loss train: 0.1053, accuracy train: 0.9506
#                   loss test: 0.1498, accuracy test: 0.8500
# Epoch 78/80 - loss train: 0.1045, accuracy train: 0.9499
#                   loss test: 0.1499, accuracy test: 0.8500
# Epoch 79/80 - loss train: 0.1038, accuracy train: 0.9520
#                   loss test: 0.1489, accuracy test: 0.8556
# Epoch 80/80 - loss train: 0.1030, accuracy train: 0.9499
#                   loss test: 0.1490, accuracy test: 0.8528
#
#
# Training Completed!

# %%
# Plot Losses and Accuracies
plt.figure(figsize=(10, 6))
plt.suptitle("Losses And Accuracies")

plt.subplot(1, 2, 2)
plt.plot(accuracy_train_list, label="Accuracy Train")
plt.plot(accuracy_test_list, label="Accuracy Test")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

plt.subplot(1, 2, 1)
plt.plot(loss_train_list, label="Loss Train")
plt.plot(loss_test_list, label="Loss Test")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()

plt.show()
